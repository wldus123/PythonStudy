# %% [markdown]
# <a href="https://colab.research.google.com/github/wldus123/PythonStudy/blob/main/untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

subjets_scores = {'국':[99,100,89,93],'영':[97,91,88,92],'수':[100,88,99,95]}
#print(subjets_scores)
df1 = pd.DataFrame(subjets_scores)
print(df1)
# Out:
#      국   영    수
# 0   99  97  100
# 1  100  91   88
# 2   89  88   99
# 3   93  92   95

# %%
import seaborn as sns

df2 = sns.load_dataset('mpg')
#print(df2.info())
# print(df2.head(3))
#print(df2['mpg'])
#df2 = df2.sort_values('mpg') #전체 데이터셋을 연비 순으로 정렬 오름차순
df2 = df2.sort_values('mpg',ascending=False) #전체 데이터셋을 연비 순으로 정렬 내림차순
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 398 entries, 322 to 28
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 31.1+ KB
# None

# %%
from numpy import median
#print(df2['horsepower'].isna()) #isna() 결측값이면 True 반환, 아니면 false
print(df2[df2['horsepower'].isna()]) #데이터프레임에서 마력이 누락된 행 추출
#df2 = df2.drop(columns="horsepower") #결측치가 있는 마력

#df2 = df2.drop(columns=['horsepower','cylinders])
#df2 = df2.dropna() #결측치가 존재하는 행 삭제 (이 데이터셋에서는 마력이 눌팍된 6개 행 삭제)
df2 = df2.dropna(subset=['horsepower']) #위와 동일하게

print(df2.info())
#print(df2.iloc[30:35]) #30 행부터 34번 행까지 출력

#df2 = df2fillna(99)
#df2 = df2.fillna(df2['horsepower'].mean()) #결측값을 마력 산술평균 값으로 채워넣음. 증량감도 사용 가능 median
# print(df2.iloc[30:35])
print(df2.describe())
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 330  40.9          4          85.0         NaN    1835          17.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 32   25.0          4          98.0         NaN    2046          19.0
# 336  23.6          4         140.0         NaN    2905          14.3
# 374  23.0          4         151.0         NaN    3035          20.5
# 126  21.0          6         200.0         NaN    2875          17.0
#
#      model_year  origin                  name
# 330          80  europe  renault lecar deluxe
# 354          81  europe           renault 18i
# 32           71     usa            ford pinto
# 336          80     usa    ford mustang cobra
# 374          82     usa        amc concord dl
# 126          74     usa         ford maverick
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 322 to 28
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ...
