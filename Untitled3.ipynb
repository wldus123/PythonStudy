# %% [markdown]
# <a href="https://colab.research.google.com/github/wldus123/PythonStudy/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

df2 = sns.load_dataset('mpg')
print(df2['horsepower'].isna())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: horsepower, Length: 398, dtype: bool

# %%
print(df2.iloc[:,[1,3]])
# Out:
#      cylinders  horsepower
# 0            8       130.0
# 1            8       165.0
# 2            8       150.0
# 3            8       150.0
# 4            8       140.0
# ..         ...         ...
# 393          4        86.0
# 394          4        52.0
# 395          4        84.0
# 396          4        79.0
# 397          4        82.0
#
# [398 rows x 2 columns]

# %%
#print(df2.groupby('cylinders')['horsepower'].mean())

print(df2.groupby('cylinders')['horsepower'].agg(['mean','median','max','count']))

#groupby 판다스에서 잘 써야함
#3기통도 있지만 짝수가 많다
# Out:
#                  mean  median    max  count
# cylinders
# 3           99.250000    98.5  110.0      4
# 4           78.281407    78.0  115.0    199
# 5           82.333333    77.0  103.0      3
# 6          101.506024   100.0  165.0     83
# 8          158.300971   150.0  230.0    103
